# %%
import pandas as pd

# %%
import json

# %%
videogames = pd.read_csv('data/videogames.csv', index_col = 0)
videogames.head()
# Out:
#                          name  \
# 0                  Spider-Man
# 1      Red Dead Redemption II
# 2          Grand Theft Auto V
# 3                  God of War
# 4  Uncharted 4: A Thief's End
#
#                                                  url    year certificate  \
# 0  https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1  https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2  https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3  https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4  https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
#
#    rating   votes                                               plot  Action  \
# 0     9.2  20,759  When a new villain threatens New York City, Pe...    True
# 1     9.7  35,703  Amidst the decline of the Wild West at the tur...    True
# 2     9.5  59,986  Three very different criminals team up for a s...    True
# ...

# %%
videogames.to_excel('data/videogames_excel.xlsx')

# %%
videogames_excel = pd.read_excel('data/videogames_excel.xlsx', index_col = 0)
videogames_excel.head()
# Out:
#                          name  \
# 0                  Spider-Man
# 1      Red Dead Redemption II
# 2          Grand Theft Auto V
# 3                  God of War
# 4  Uncharted 4: A Thief's End
#
#                                                  url    year certificate  \
# 0  https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1  https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2  https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3  https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4  https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
#
#    rating   votes                                               plot  Action  \
# 0     9.2  20,759  When a new villain threatens New York City, Pe...    True
# 1     9.7  35,703  Amidst the decline of the Wild West at the tur...    True
# 2     9.5  59,986  Three very different criminals team up for a s...    True
# ...

# %%
type(videogames)
# Out:
# pandas.core.frame.DataFrame

# %%
type(videogames_excel)
# Out:
# pandas.core.frame.DataFrame

# %%
videogames_excel.to_csv('data/videogames_csv.csv')

# %%
with open('data/personal.json') as f:
    personal = json.load(f)

# %%
type(personal)
# Out:
# dict

# %%
personal['workers']
# Out:
# [{'nombre': 'Ana',
#   'edad': 34,
#   'experiencia': 5,
#   'nivel': 'Senior',
#   'salario': 50000,
#   'mascota': 'gatos'},
#  {'nombre': 'Eva',
#   'edad': 37,
#   'experiencia': 2,
#   'nivel': 'Mid',
#   'salario': 35000},
#  {'nombre': 'Marta',
#   'edad': 27,
#   'experiencia': 1,
#   'nivel': 'Junior',
#   'salario': 25000},
#  {'nombre': 'Paula',
#   'edad': 30,
#   'experiencia': 3,
#   'nivel': 'Mid',
#   'salario': 35000}]

# %%
personal_normalizado = pd.json_normalize(personal['workers'])

# %%
personal_normalizado.head()
# Out:
#   nombre  edad  experiencia   nivel  salario mascota
# 0    Ana    34            5  Senior    50000   gatos
# 1    Eva    37            2     Mid    35000     NaN
# 2  Marta    27            1  Junior    25000     NaN
# 3  Paula    30            3     Mid    35000     NaN
